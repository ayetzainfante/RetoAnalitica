# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("dataset.csv", encoding="latin1")
# Out:
# <ipython-input-5-f78576d6fc2c>:1: DtypeWarning: Columns (0,2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("dataset.csv", encoding="latin1")

# %%
print(df.columns)
# Out:
# Index(['Programa/Fondo', 'Clave', 'Nombre del proyecto',
#        'Nombre del beneficiario', ' Monto de apoyo ', 'Unnamed: 5',
#        'Unnamed: 6'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Programa/Fondo           297 non-null    object
#  1   Clave                    297 non-null    float64
#  2   Nombre del proyecto      297 non-null    object
#  3   Nombre del beneficiario  297 non-null    object
#  4    Monto de apoyo          297 non-null    float64
#  5   Unnamed: 5               0 non-null      float64
#  6   Unnamed: 6               1 non-null      float64
# dtypes: float64(4), object(3)
# memory usage: 56.0+ MB

# %%
df.describe()
# Out:
#              Clave   Monto de apoyo   Unnamed: 5  Unnamed: 6
# count   297.000000      2.970000e+02         0.0         1.0
# mean   6970.286195      3.490875e+05         NaN    194000.0
# std     240.801622      7.350379e+05         NaN         NaN
# min    4725.000000      3.594520e+03         NaN    194000.0
# 25%    6862.000000      3.111552e+04         NaN    194000.0
# 50%    7019.000000      5.859452e+04         NaN    194000.0
# 75%    7145.000000      2.760000e+05         NaN    194000.0
# max    7271.000000      4.996200e+06         NaN    194000.0

# %%
sns.countplot(data=df, y='Programa/Fondo')
# Out:
# <Axes: xlabel='count', ylabel='Programa/Fondo'>

# %%
sns.histplot(data=df, x=' Monto de apoyo ', bins=5)
# Out:
# <Axes: xlabel=' Monto de apoyo ', ylabel='Count'>

# %% [markdown]
# De los 297 apoyos totales brindados, más de 250 fueron de un monto menor o igual a $1,000,000

# %%
sns.scatterplot(data=df, y="Programa/Fondo", x=" Monto de apoyo ")
# Out:
# <Axes: xlabel=' Monto de apoyo ', ylabel='Programa/Fondo'>

# %%
sns.boxplot(data=df, y="Programa/Fondo", x=" Monto de apoyo ")
# Out:
# <Axes: xlabel=' Monto de apoyo ', ylabel='Programa/Fondo'>

# %%
df_corr = df.corr()
df_corr
# Out:
# <ipython-input-70-0c96883f2151>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_corr = df.corr()
#                      Clave   Monto de apoyo   Unnamed: 5  Unnamed: 6
# Clave             1.000000         -0.188871         NaN         NaN
#  Monto de apoyo  -0.188871          1.000000         NaN         NaN
# Unnamed: 5             NaN               NaN         NaN         NaN
# Unnamed: 6             NaN               NaN         NaN         NaN

# %%
sns.heatmap(data=df_corr , vmin=-1, vmax=1, cmap ="BuPu", annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Para los fines de nuestro análisis, no se requiere un heatmap, ya que los datos cuantitativos no son suficientes para generar un heatmap preciso y aplicable
